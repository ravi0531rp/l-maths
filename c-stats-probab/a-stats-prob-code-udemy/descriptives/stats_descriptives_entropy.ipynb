# %% [markdown]
# ## Entropy

# %%
# import libraries
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
## "discrete" entropy

# generate data
N = 1000
numbers = np.ceil( 8*np.random.rand(N)**2 )
numbers[numbers==7] = 4
plt.plot(numbers,'o')

# %%
np.finfo(float).eps
# Out:
# 2.220446049250313e-16

# %%
## "discrete" entropy

# generate data
N = 1000
numbers = np.ceil( 8*np.random.rand(N)**2 )


# get counts and probabilities
u = np.unique(numbers) # find unique numbers and then their counts
probs = np.zeros(len(u))

for ui in range(len(u)):
    probs[ui] = sum(numbers==u[ui]) / N

    
# compute entropy
entropee = -sum( probs*np.log2(probs+np.finfo(float).eps) ) # the last part is added there to avoid log(0) if there's any case


# plot
plt.bar(u,probs)
plt.title('Entropy = %g'%entropee)
plt.xlabel('Data value')
plt.ylabel('Probability')
plt.show()

# %%
## for random variables

# create Brownian noise ; the long term growth of stock market can be modelled by this noise + some uptrend
N = 1123
brownnoise = np.cumsum( np.sign(np.random.randn(N)) )

fig,ax = plt.subplots(2,1,figsize=(4,6))
ax[0].plot(brownnoise)
ax[0].set_xlabel('Data index')
ax[0].set_ylabel('Data value')
ax[0].set_title('Brownian noise')

ax[1].hist(brownnoise,30)
ax[1].set_xlabel('Data value')
ax[1].set_ylabel('Counts')
plt.show()

# %%
### now compute entropy
# number of bins
nbins = 50

# bin the data and convert to probability
nPerBin,bins = np.histogram(brownnoise,nbins)
probs = nPerBin / sum(nPerBin)

# compute entropy
entro = -sum( probs*np.log2(probs+np.finfo(float).eps) ) # sensitive to nbins

print('Entropy = %g'%entro)
# Out:
# Entropy = 4.82462

# %%
bins
# Out:
# array([-21.  , -20.34, -19.68, -19.02, -18.36, -17.7 , -17.04, -16.38,
#        -15.72, -15.06, -14.4 , -13.74, -13.08, -12.42, -11.76, -11.1 ,
#        -10.44,  -9.78,  -9.12,  -8.46,  -7.8 ,  -7.14,  -6.48,  -5.82,
#         -5.16,  -4.5 ,  -3.84,  -3.18,  -2.52,  -1.86,  -1.2 ,  -0.54,
#          0.12,   0.78,   1.44,   2.1 ,   2.76,   3.42,   4.08,   4.74,
#          5.4 ,   6.06,   6.72,   7.38,   8.04,   8.7 ,   9.36,  10.02,
#         10.68,  11.34,  12.  ])

# %%
nPerBin
# Out:
# array([ 1,  6,  0, 14, 16,  0, 22, 28,  0, 25, 23,  0, 29, 40,  0, 46, 63,
#         0, 77, 73,  0, 68, 67,  0, 59, 40,  0, 32, 39,  0, 38, 30,  0, 28,
#        31,  0, 37, 34,  0, 29, 24,  0, 23, 26,  0, 28, 19,  0,  6,  2],
#       dtype=int64)
